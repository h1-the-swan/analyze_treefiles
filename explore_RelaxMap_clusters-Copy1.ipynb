# %%
import sys, os, time
from glob import glob

# %%
from sqlalchemy import create_engine, MetaData, select

# %%
import pandas as pd
import numpy as np

# %%
engine = create_engine('mysql+mysqldb://jason:password@localhost/wos')
metadata = MetaData(engine)
metadata.reflect()

# %%
def get_query_result(uids, engine, metadata):
    tbl = metadata.tables['pubInfo_minimal']
    sq = tbl.select(tbl.c.UID.in_(uids))
    df_result = pd.read_sql(sq, engine)
    return df_result

# %%
def interpret_query_result(df_result):
    d = dict()
    d['counts'] = dict()
    for colname in df_result.columns.tolist():
        notnull = df_result[colname].notnull().sum()
        d['counts'][colname] = notnull
    d['heading_value_counts'] = df_result['heading'].value_counts()
    d['pubyear_value_counts'] = df_result['pubyear'].value_counts()
    d['subheading_value_counts'] = df_result['subheading'].value_counts()
    d['subject_extended_value_counts'] = df_result['subject_extended'].value_counts()
    d['title_source_value_counts'] = df_result['title_source'].value_counts()
    return d

# %%
def parse_tree_one_line(line):
    line = line.strip().split(' ')
    cl = line[0]
    paper_id = line[2].strip('"')
    return paper_id, cl

def parse_tree(fname):
    with open(fname, 'r') as f:
        rows = []
        for line in f:
            if line[0] != "#":
                row = parse_tree_one_line(line)
                rows.append(row)
                
    df = pd.DataFrame(rows, columns=['UID', 'cl'])
    
    df['cl_bottom'] = df['cl'].apply(lambda x: ':'.join(x.split(':')[:-1]))

    df['cl_top'] = df['cl'].apply(lambda x: x.split(':')[0])
    
    return df

# %%
def get_results_for_multiple_clusters(df_tree, n=10, engine=engine, metadata=metadata):
    # get results for biggest n clusters from one tree file
    d = dict()
    i = 0
    for cl, cnt in df_tree['cl_bottom'].value_counts().iteritems():
        d[cl] = dict()
        d[cl]['total_count'] = cnt
        subset = df_tree[df_tree['cl_bottom']==cl]
        uids = subset['UID'].tolist()
        df_result = get_query_result(uids, engine, metadata)
        d_result = interpret_query_result(df_result)
        for k, v in d_result.items():
            d[cl][k] = v
        i += 1
        if i == n:
            break
    return d

# %%
def get_fname_from_number(number):
    g = glob('data/relaxmap_cluster_treefiles/wos_{}_cluster*.tree'.format(number))
    if len(g) == 1:
        return g[0]
    else:
        raise RuntimeError("number: {} -- file not found".format(number))

# %%
fname = get_fname_from_number(4)
df_tree = parse_tree(fname)

# %%
def get_df_result_stepwise(df_tree, step=5000):
    start = time.clock()
    uids = df_tree['UID']
    df_result = pd.DataFrame([])
    step = 5000
    for i in range(0, len(uids), step):
        uids_subset = uids[i:min(i+step, len(uids))]
        df_subset = get_query_result(uids_subset, engine, metadata)
        if df_result.empty:
            df_result = df_subset
        else:
            df_result = df_result.append(df_subset)
        # print("{}:{}. Shape: {}".format(i, min(i+step, len(uids)), df_result.shape))
    end = time.clock()
    print("done. took {:.1f} seconds".format(end-start))
    return df_result

# %%
def get_results_one_cluster(fname):
    df_tree = parse_tree(fname)
    # fname_tail = os.path.split(fname)[1]
    step = max(df_tree.shape[0]/20, 5000)
    df_result = get_df_result_stepwise(df_tree, step=step)
    d_result = interpret_query_result(df_result)
    return d_result

# %%
g = glob('data/relaxmap_cluster_treefiles/*.tree')

# %%
# %%time
d = {}
for fname in g:
    print('getting results for {}'.format(fname))
    fname_tail = os.path.split(fname)[1]
    d_result = get_results_one_cluster(fname)
    d[fname_tail] = {
        'num_results': d_result['counts']['UID'],
        'subject_extended_value_counts': d_result['subject_extended_value_counts']
    }
# Out:
# getting results for data/relaxmap_cluster_treefiles/wos_59_cluster_2858839.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_60_cluster_5084895.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_49_cluster_12269262.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_73_cluster_7053040.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_62_cluster_8956094.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_77_cluster_1223978.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_57_cluster_1769913.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_4_cluster_5639372.tree
# done. took 2.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_71_cluster_4328450.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_64_cluster_5141762.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_43_cluster_5483683.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_67_cluster_7296402.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_69_cluster_1021261.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_7_cluster_1935800.tree
# done. took 2.7 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_21_cluster_8376148.tree
# done. took 1.8 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_56_cluster_1874358.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_58_cluster_5639449.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_27_cluster_2479591.tree
# done. took 1.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_88_cluster_7184875.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_80_cluster_3135267.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_61_cluster_2920285.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_66_cluster_297571.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_84_cluster_5708559.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_46_cluster_4984947.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_33_cluster_1110664.tree
# done. took 1.5 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_53_cluster_902337.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_95_cluster_1305858.tree
# done. took 0.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_39_cluster_9878157.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_28_cluster_1349764.tree
# done. took 1.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_30_cluster_574535.tree
# done. took 1.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_87_cluster_12058315.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_3_cluster_6245469.tree
# done. took 3.5 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_9_cluster_6497556.tree
# done. took 2.5 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_55_cluster_6872317.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_54_cluster_12334824.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_94_cluster_4487681.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_22_cluster_3058305.tree
# done. took 1.7 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_52_cluster_5155271.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_36_cluster_2238039.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_90_cluster_3390230.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_92_cluster_10889927.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_23_cluster_4494585.tree
# done. took 1.7 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_20_cluster_1029834.tree
# done. took 1.8 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_63_cluster_7972482.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_96_cluster_1336207.tree
# done. took 0.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_97_cluster_1896441.tree
# done. took 0.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_44_cluster_2445042.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_29_cluster_4669990.tree
# done. took 1.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_13_cluster_7542179.tree
# done. took 2.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_41_cluster_4672673.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_81_cluster_612112.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_76_cluster_5038413.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_85_cluster_9836036.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_72_cluster_12414762.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_15_cluster_6988379.tree
# done. took 1.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_100_cluster_2863730.tree
# done. took 0.8 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_79_cluster_2928019.tree
# done. took 0.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_18_cluster_3312946.tree
# done. took 1.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_78_cluster_7801166.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_86_cluster_5481073.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_5_cluster_7371898.tree
# done. took 3.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_19_cluster_5814431.tree
# done. took 1.8 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_93_cluster_7457291.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_51_cluster_11466837.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_48_cluster_5973006.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_68_cluster_7525588.tree
# done. took 1.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_34_cluster_1841286.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_38_cluster_3915539.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_11_cluster_8808000.tree
# done. took 2.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_25_cluster_2929392.tree
# done. took 1.7 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_16_cluster_6573861.tree
# done. took 1.9 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_10_cluster_808980.tree
# done. took 2.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_82_cluster_3368383.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_83_cluster_2903382.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_89_cluster_8146573.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_37_cluster_10141005.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_70_cluster_6605979.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_50_cluster_5083869.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_2_cluster_4654150.tree
# done. took 4.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_17_cluster_2864584.tree
# done. took 1.8 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_75_cluster_4016667.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_35_cluster_5173234.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_32_cluster_4800899.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_26_cluster_3234467.tree
# done. took 1.7 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_74_cluster_426283.tree
# done. took 1.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_31_cluster_5598766.tree
# done. took 1.6 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_12_cluster_1889140.tree
# done. took 2.1 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_99_cluster_10720328.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_40_cluster_1030005.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_98_cluster_3854558.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_47_cluster_4409637.tree
# done. took 1.4 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_14_cluster_2748381.tree
# done. took 2.2 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_6_cluster_6273522.tree
# done. took 3.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_65_cluster_12430129.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_91_cluster_2085455.tree
# done. took 1.0 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_42_cluster_4145452.tree
# done. took 1.5 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_45_cluster_6578112.tree
# done. took 1.3 seconds
# getting results for data/relaxmap_cluster_treefiles/wos_24_cluster_10026951.tree
# done. took 1.7 seconds
# CPU times: user 2min 40s, sys: 1.37 s, total: 2min 41s
# Wall time: 22min 11s

# %%
import cPickle as pickle
with open('relaxmap_cluster_subject_extended_data.pickle', 'wb') as outf:
    pickle.dump(d, outf)

# %%
for k, v in d.items():
    print(k)
    print(v['subject_extended_value_counts'][0:3])
    print
# Out:
# wos_71_cluster_4328450.tree
# Chemistry              4844
# Cell Biology           4764
# Genetics & Heredity    3617
# Name: subject_extended, dtype: int64
#
# wos_12_cluster_1889140.tree
# Virology                               7876
# Immunology                             4822
# Science & Technology - Other Topics    2611
# Name: subject_extended, dtype: int64
#
# wos_27_cluster_2479591.tree
# Materials Science    9684
# Chemistry            3451
# Cell Biology         3133
# Name: subject_extended, dtype: int64
#
# wos_88_cluster_7184875.tree
# Neurosciences & Neurology    5177
# Ophthalmology                4669
# Physiology                   2111
# Name: subject_extended, dtype: int64
#
# wos_17_cluster_2864584.tree
# Pediatrics    4033
# Physiology    3524
# Chemistry     2259
# Name: subject_extended, dtype: int64
#
# wos_60_cluster_5084895.tree
# Genetics & Heredity          3741
# Neurosciences & Neurology    3690
# Physiology                   2018
# Name: subject_extended, dtype: int64
#
# wos_73_cluster_7053040.tree
# Virology               5868
# Veterinary Sciences    1836
# Chemistry              1615
# Name: subject_extended, dtype: int64
#
# wos_84_cluster_5708559.tree
# Hematology             4608
# Oncology               1435
# Veterinary Sciences    1035
# Name: subject_extended, dtype: int64
#
# wos_37_cluster_10141005.tree
# Neurosciences & Neurology    4350
# Psychiatry                   3572
# Pharmacology & Pharmacy      3538
# Name: subject_extended, dtype: int64
#
# wos_44_cluster_2445042.tree
# Physics                     16666
# Astronomy & Astrophysics     4781
# Optics                        599
# Name: subject_extended, dtype: int64
#
# wos_85_cluster_9836036.tree
# Sport Sciences                                 4259
# Public, Environmental & Occupational Health    3527
# General & Internal Medicine                    2142
# Name: subject_extended, dtype: int64
#
# wos_92_cluster_10889927.tree
# Endocrinology & Metabolism    2547
# Nutrition & Dietetics         1819
# Nursing                       1559
# Name: subject_extended, dtype: int64
#
# wos_95_cluster_1305858.tree
# Neurosciences & Neurology              6843
# Science & Technology - Other Topics     884
# Cell Biology                            853
# Name: subject_extended, dtype: int64
#
# wos_53_cluster_902337.tree
# Chemistry            16116
# Crystallography       5721
# Materials Science     2894
# Name: subject_extended, dtype: int64
#
# wos_77_cluster_1223978.tree
# Cell Biology                           2986
# Science & Technology - Other Topics    2948
# Biochemistry & Molecular Biology       2827
# Name: subject_extended, dtype: int64
#
# wos_20_cluster_1029834.tree
# Zoology            2748
# Transplantation    2738
# Polymer Science    2333
# Name: subject_extended, dtype: int64
#
# wos_63_cluster_7972482.tree
# Surgery                               4284
# Cardiovascular System & Cardiology    3747
# Gastroenterology & Hepatology         2844
# Name: subject_extended, dtype: int64
#
# wos_45_cluster_6578112.tree
# Surgery                                          6042
# Radiology, Nuclear Medicine & Medical Imaging    2071
# General & Internal Medicine                      2060
# Name: subject_extended, dtype: int64
#
# wos_18_cluster_3312946.tree
# Dentistry, Oral Surgery & Medicine    8360
# Cardiovascular System & Cardiology    4549
# Microbiology                          2664
# Name: subject_extended, dtype: int64
#
# wos_13_cluster_7542179.tree
# Chemistry            9824
# Materials Science    7440
# Physics              6403
# Name: subject_extended, dtype: int64
#
# wos_57_cluster_1769913.tree
# Chemistry          4122
# Polymer Science    2891
# Oncology           1944
# Name: subject_extended, dtype: int64
#
# wos_55_cluster_6872317.tree
# Chemistry                           2784
# Biochemistry & Molecular Biology    2231
# Plant Sciences                      1686
# Name: subject_extended, dtype: int64
#
# wos_98_cluster_3854558.tree
# Endocrinology & Metabolism    5379
# Oncology                      2004
# Cell Biology                  1354
# Name: subject_extended, dtype: int64
#
# wos_81_cluster_612112.tree
# Psychology              10977
# Oncology                  781
# Business & Economics      639
# Name: subject_extended, dtype: int64
#
# wos_30_cluster_574535.tree
# Pharmacology & Pharmacy             5405
# Neurosciences & Neurology           3682
# Biochemistry & Molecular Biology    2590
# Name: subject_extended, dtype: int64
#
# wos_15_cluster_6988379.tree
# Physics              20029
# Materials Science    10084
# Chemistry             3640
# Name: subject_extended, dtype: int64
#
# wos_52_cluster_5155271.tree
# Immunology                   4519
# Neurosciences & Neurology    4010
# Psychology                   2603
# Name: subject_extended, dtype: int64
#
# wos_59_cluster_2858839.tree
# Gastroenterology & Hepatology    7436
# Microbiology                     3527
# General & Internal Medicine      1909
# Name: subject_extended, dtype: int64
#
# wos_51_cluster_11466837.tree
# Physics              16399
# Materials Science     4320
# Chemistry             1271
# Name: subject_extended, dtype: int64
#
# wos_99_cluster_10720328.tree
# Endocrinology & Metabolism            5350
# Cardiovascular System & Cardiology    1489
# Physiology                            1206
# Name: subject_extended, dtype: int64
#
# wos_87_cluster_12058315.tree
# Virology                            2130
# Biochemistry & Molecular Biology    1255
# Infectious Diseases                 1231
# Name: subject_extended, dtype: int64
#
# wos_35_cluster_5173234.tree
# Chemistry                             8143
# Physics                               3741
# Cardiovascular System & Cardiology    1395
# Name: subject_extended, dtype: int64
#
# wos_4_cluster_5639372.tree
# Astronomy & Astrophysics               43887
# Physics                                 2046
# Science & Technology - Other Topics     1008
# Name: subject_extended, dtype: int64
#
# wos_36_cluster_2238039.tree
# Cardiovascular System & Cardiology    4139
# General & Internal Medicine           2632
# Biochemistry & Molecular Biology      2385
# Name: subject_extended, dtype: int64
#
# wos_25_cluster_2929392.tree
# Physics              6743
# Engineering          2901
# Materials Science    2361
# Name: subject_extended, dtype: int64
#
# wos_9_cluster_6497556.tree
# Endocrinology & Metabolism          7227
# Biochemistry & Molecular Biology    5291
# Cell Biology                        4812
# Name: subject_extended, dtype: int64
#
# wos_46_cluster_4984947.tree
# Food Science & Technology    7626
# Nutrition & Dietetics        4405
# Pharmacology & Pharmacy      2890
# Name: subject_extended, dtype: int64
#
# wos_91_cluster_2085455.tree
# Cardiovascular System & Cardiology    3648
# Pharmacology & Pharmacy               2664
# Physiology                            1634
# Name: subject_extended, dtype: int64
#
# wos_65_cluster_12430129.tree
# Gastroenterology & Hepatology    8153
# Virology                         5207
# General & Internal Medicine      2245
# Name: subject_extended, dtype: int64
#
# wos_31_cluster_5598766.tree
# Business & Economics                        19429
# Operations Research & Management Science     2604
# Engineering                                  1726
# Name: subject_extended, dtype: int64
#
# wos_66_cluster_297571.tree
# Marine & Freshwater Biology         3462
# Environmental Sciences & Ecology    2524
# Oceanography                        1892
# Name: subject_extended, dtype: int64
#
# wos_78_cluster_7801166.tree
# Cardiovascular System & Cardiology    2501
# Veterinary Sciences                   2410
# General & Internal Medicine           2217
# Name: subject_extended, dtype: int64
#
# wos_21_cluster_8376148.tree
# Cell Biology                        6608
# Oncology                            4003
# Biochemistry & Molecular Biology    2651
# Name: subject_extended, dtype: int64
#
# wos_41_cluster_4672673.tree
# Psychiatry                          4527
# Microbiology                        2362
# Biochemistry & Molecular Biology    2321
# Name: subject_extended, dtype: int64
#
# wos_89_cluster_8146573.tree
# Biochemistry & Molecular Biology    2528
# Biophysics                          1412
# Rheumatology                        1279
# Name: subject_extended, dtype: int64
#
# wos_56_cluster_1874358.tree
# Microbiology           4550
# Infectious Diseases    3164
# Virology               3000
# Name: subject_extended, dtype: int64
#
# wos_90_cluster_3390230.tree
# Physics                                4388
# Immunology                             3271
# Science & Technology - Other Topics    1441
# Name: subject_extended, dtype: int64
#
# wos_49_cluster_12269262.tree
# Cell Biology                        3549
# Immunology                          3209
# Biochemistry & Molecular Biology    2679
# Name: subject_extended, dtype: int64
#
# wos_82_cluster_3368383.tree
# Marine & Freshwater Biology         8171
# Environmental Sciences & Ecology    4536
# Water Resources                     2285
# Name: subject_extended, dtype: int64
#
# wos_28_cluster_1349764.tree
# Electrochemistry     4820
# Chemistry            4005
# Materials Science    3838
# Name: subject_extended, dtype: int64
#
# wos_39_cluster_9878157.tree
# Immunology             4257
# Infectious Diseases    1991
# Microbiology           1908
# Name: subject_extended, dtype: int64
#
# wos_47_cluster_4409637.tree
# Immunology                          3476
# Biochemistry & Molecular Biology    3348
# Environmental Sciences & Ecology    1922
# Name: subject_extended, dtype: int64
#
# wos_67_cluster_7296402.tree
# Gastroenterology & Hepatology    5591
# Virology                         4169
# General & Internal Medicine      1700
# Name: subject_extended, dtype: int64
#
# wos_80_cluster_3135267.tree
# Dentistry, Oral Surgery & Medicine    7656
# Engineering                           2010
# Materials Science                     1197
# Name: subject_extended, dtype: int64
#
# wos_58_cluster_5639449.tree
# Cell Biology           4757
# Oncology               4084
# Genetics & Heredity    2014
# Name: subject_extended, dtype: int64
#
# wos_2_cluster_4654150.tree
# Plant Sciences          8598
# Cell Biology            6846
# Business & Economics    6022
# Name: subject_extended, dtype: int64
#
# wos_79_cluster_2928019.tree
# Oncology                            2638
# General & Internal Medicine         1366
# Biochemistry & Molecular Biology    1234
# Name: subject_extended, dtype: int64
#
# wos_14_cluster_2748381.tree
# Neurosciences & Neurology           9918
# Biochemistry & Molecular Biology    3323
# Physics                             3058
# Name: subject_extended, dtype: int64
#
# wos_75_cluster_4016667.tree
# Oncology                   5430
# Pathology                  1429
# Pharmacology & Pharmacy    1331
# Name: subject_extended, dtype: int64
#
# wos_16_cluster_6573861.tree
# Physics       8500
# Psychiatry    7135
# Chemistry     4288
# Name: subject_extended, dtype: int64
#
# wos_40_cluster_1030005.tree
# Physics              9047
# Chemistry            6877
# Materials Science    1192
# Name: subject_extended, dtype: int64
#
# wos_6_cluster_6273522.tree
# Geology                      23537
# Geochemistry & Geophysics    13497
# Mineralogy                    9826
# Name: subject_extended, dtype: int64
#
# wos_10_cluster_808980.tree
# Chemistry            7730
# Materials Science    3231
# Engineering          3021
# Name: subject_extended, dtype: int64
#
# wos_69_cluster_1021261.tree
# Physics             10991
# Chemistry            2758
# Computer Science     2242
# Name: subject_extended, dtype: int64
#
# wos_5_cluster_7371898.tree
# Chemistry            10824
# Physics              10606
# Materials Science     8254
# Name: subject_extended, dtype: int64
#
# wos_83_cluster_2903382.tree
# Agriculture                         10947
# Environmental Sciences & Ecology     2115
# Plant Sciences                       1069
# Name: subject_extended, dtype: int64
#
# wos_62_cluster_8956094.tree
# Physics                                19404
# Optics                                  2150
# Science & Technology - Other Topics      736
# Name: subject_extended, dtype: int64
#
# wos_7_cluster_1935800.tree
# Zoology                      6019
# Neurosciences & Neurology    4966
# Cell Biology                 4287
# Name: subject_extended, dtype: int64
#
# wos_93_cluster_7457291.tree
# Developmental Biology    3860
# Genetics & Heredity      2449
# Cell Biology             2040
# Name: subject_extended, dtype: int64
#
# wos_68_cluster_7525588.tree
# Biochemistry & Molecular Biology    5726
# Biophysics                          3273
# Chemistry                           2527
# Name: subject_extended, dtype: int64
#
# wos_48_cluster_5973006.tree
# Meteorology & Atmospheric Sciences    13926
# Oceanography                           2827
# Geology                                2347
# Name: subject_extended, dtype: int64
#
# wos_61_cluster_2920285.tree
# Endocrinology & Metabolism     7339
# General & Internal Medicine    2717
# Chemistry                      1580
# Name: subject_extended, dtype: int64
#
# wos_64_cluster_5141762.tree
# Chemistry                    1587
# Oncology                     1416
# Neurosciences & Neurology    1336
# Name: subject_extended, dtype: int64
#
# wos_34_cluster_1841286.tree
# Geology                                9908
# Paleontology                           5798
# Science & Technology - Other Topics    2606
# Name: subject_extended, dtype: int64
#
# wos_23_cluster_4494585.tree
# Astronomy & Astrophysics      8072
# Endocrinology & Metabolism    3932
# Geology                       3777
# Name: subject_extended, dtype: int64
#
# wos_86_cluster_5481073.tree
# Pharmacology & Pharmacy      3280
# Plant Sciences               3197
# Neurosciences & Neurology    2720
# Name: subject_extended, dtype: int64
#
# wos_33_cluster_1110664.tree
# Pharmacology & Pharmacy             5155
# Microbiology                        3547
# Biochemistry & Molecular Biology    2661
# Name: subject_extended, dtype: int64
#
# wos_100_cluster_2863730.tree
# Business & Economics              8567
# Psychology                        5672
# Social Sciences - Other Topics     979
# Name: subject_extended, dtype: int64
#
# wos_76_cluster_5038413.tree
# Endocrinology & Metabolism    3673
# Pharmacology & Pharmacy       2416
# Neurosciences & Neurology     1316
# Name: subject_extended, dtype: int64
#
# wos_43_cluster_5483683.tree
# Immunology                          5615
# Chemistry                           2537
# Biochemistry & Molecular Biology    1946
# Name: subject_extended, dtype: int64
#
# wos_11_cluster_8808000.tree
# Psychology                            7557
# Cardiovascular System & Cardiology    3532
# Psychiatry                            2851
# Name: subject_extended, dtype: int64
#
# wos_96_cluster_1336207.tree
# Biochemistry & Molecular Biology    3642
# Respiratory System                  1978
# Cell Biology                        1532
# Name: subject_extended, dtype: int64
#
# wos_72_cluster_12414762.tree
# Polymer Science              4939
# Neurosciences & Neurology    2232
# Physics                      1713
# Name: subject_extended, dtype: int64
#
# wos_22_cluster_3058305.tree
# Astronomy & Astrophysics               24482
# Physics                                  868
# Science & Technology - Other Topics      494
# Name: subject_extended, dtype: int64
#
# wos_70_cluster_6605979.tree
# Immunology                 2558
# Microbiology               2410
# Pharmacology & Pharmacy    1959
# Name: subject_extended, dtype: int64
#
# wos_3_cluster_6245469.tree
# Physics            17018
# Polymer Science     6780
# Chemistry           5714
# Name: subject_extended, dtype: int64
#
# wos_74_cluster_426283.tree
# Pharmacology & Pharmacy             4999
# Oncology                            3180
# Biochemistry & Molecular Biology    2240
# Name: subject_extended, dtype: int64
#
# wos_24_cluster_10026951.tree
# Physics              26577
# Materials Science     2350
# Optics                1505
# Name: subject_extended, dtype: int64
#
# wos_38_cluster_3915539.tree
# Materials Science            6158
# Chemistry                    5753
# Neurosciences & Neurology    2623
# Name: subject_extended, dtype: int64
#
# wos_26_cluster_3234467.tree
# Physics                                       22060
# Zoology                                        1537
# Life Sciences & Biomedicine - Other Topics      800
# Name: subject_extended, dtype: int64
#
# wos_54_cluster_12334824.tree
# Biochemistry & Molecular Biology        3672
# Biotechnology & Applied Microbiology    3371
# Microbiology                            2548
# Name: subject_extended, dtype: int64
#
# wos_19_cluster_5814431.tree
# Neurosciences & Neurology    3918
# Immunology                   3746
# Chemistry                    3627
# Name: subject_extended, dtype: int64
#
# wos_29_cluster_4669990.tree
# Pharmacology & Pharmacy      5262
# Neurosciences & Neurology    4830
# Physiology                   3438
# Name: subject_extended, dtype: int64
#
# wos_97_cluster_1896441.tree
# Orthopedics                         2674
# Surgery                             2459
# Biochemistry & Molecular Biology    1133
# Name: subject_extended, dtype: int64
#
# wos_94_cluster_4487681.tree
# Virology                       3354
# Pediatrics                     2566
# General & Internal Medicine    1880
# Name: subject_extended, dtype: int64
#
# wos_32_cluster_4800899.tree
# Physics                             10058
# Pharmacology & Pharmacy              2973
# Biochemistry & Molecular Biology     2347
# Name: subject_extended, dtype: int64
#
# wos_42_cluster_4145452.tree
# Psychiatry      6668
# Psychology      4415
# Spectroscopy    4061
# Name: subject_extended, dtype: int64
#
# wos_50_cluster_5083869.tree
# Nutrition & Dietetics                 3259
# Reproductive Biology                  3012
# Cardiovascular System & Cardiology    1620
# Name: subject_extended, dtype: int64

# %%
for i in range(20, 30):
    try:
        fname = os.path.split(get_fname_from_number(i))[1]
    except RuntimeError:
        continue
    print(fname)
    x = d[fname]['subject_extended_value_counts']
    j = 0
    for subject, c in x.iteritems():
        print(subject)
        j += 1
        if j == 3:
            break
    print("")
# Out:
# wos_20_cluster_1029834.tree
# Zoology
# Transplantation
# Polymer Science
#
# wos_21_cluster_8376148.tree
# Cell Biology
# Oncology
# Biochemistry & Molecular Biology
#
# wos_22_cluster_3058305.tree
# Astronomy & Astrophysics
# Physics
# Science & Technology - Other Topics
#
# wos_23_cluster_4494585.tree
# Astronomy & Astrophysics
# Endocrinology & Metabolism
# Geology
#
# wos_24_cluster_10026951.tree
# Physics
# Materials Science
# Optics
#
# wos_25_cluster_2929392.tree
# Physics
# Engineering
# Materials Science
#
# wos_26_cluster_3234467.tree
# Physics
# Zoology
# Life Sciences & Biomedicine - Other Topics
#
# wos_27_cluster_2479591.tree
# Materials Science
# Chemistry
# Cell Biology
#
# wos_28_cluster_1349764.tree
# Electrochemistry
# Chemistry
# Materials Science
#
# wos_29_cluster_4669990.tree
# Pharmacology & Pharmacy
# Neurosciences & Neurology
# Physiology
